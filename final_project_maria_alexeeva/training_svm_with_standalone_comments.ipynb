# %%
import numpy as np
from tqdm import tqdm
import pickle
import sklearn
from sklearn import svm
from sklearn.svm import LinearSVC
np.set_printoptions(threshold=np.nan)
from sklearn.utils import shuffle
from sklearn.model_selection import cross_val_score

# %%
#loading training data (uses flattened data generated by Yiyun Zhao)
flatten_train_x = np.load('flatten_data/flat_train_x.npy', mmap_mode='r')
flatten_train_y = np.load('flatten_data/flat_train_y.npy', mmap_mode='r')

# %%
print(flatten_train_x.shape)
# Out:
# (5217, 314)

# %%
print(flatten_train_y.shape)
# Out:
# (5217, 4)

# %%
#changing the format of the gold labels from categorical to class labels in the train set
y_list = []
for item in np.asarray(flatten_train_y):
    index = np.where(item == 1)
    #print(item, index[0][0])
    y_list.append(index[0][0])

train_y = np.asarray(y_list)
print(train_y.shape)
# Out:
# (5217,)

# %%
#load test data (the file is called 'dev' because the original provided dataset did not include test data,
#only dev data, so dev set was used as test)
flatten_dev_x = np.load('flatten_data/flat_dev_x.npy', mmap_mode='r')
flatten_dev_y = np.load('flatten_data/flat_dev_y.npy', mmap_mode='r')

# %%
print(flatten_dev_y.shape)
print(flatten_dev_y.shape)
# Out:
# (1485, 4)
# (1485, 4)

# %%
#changing the format of the gold labels from categorical to class labels in the test set
dev_y_list = []

for item in np.asarray(flatten_dev_y):
    index = np.where(item == 1)
    #print(item, index[0][0])
    dev_y_list.append(index[0][0])

dev_y = np.asarray(dev_y_list)

# %%
print(dev_y.shape)
# Out:
# (1485,)

# %%
#shuffle the data
flatten_train_x, train_y = shuffle(flatten_train_x, train_y)

# %%
#Doing cross validation
cross_val_score(clf, flatten_train_x, train_y, scoring='f1_macro', cv=5)
# Out:
# /home/masha/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/masha/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# array([0.32688774, 0.35907328, 0.38164696, 0.41278042, 0.18673869])

# %%
#Training the model
clf = LinearSVC()
clf.fit(flatten_train_x, train_y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
#serializing
#pickle.dump(clf, open("model_svm_just_comment_vector.pickle", 'wb'))
